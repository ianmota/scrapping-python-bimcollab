# %% [markdown]
# #Coleta de dados

# %%
from backend.scrapper.scrapper import ScrapperResearch, ScrapperColect
from data.dataSave import dbBuildCSV

email = "oscarfreire@projete5d.com.br"
password = "@Timeprojete5d"
local_save = "data"

browser = ScrapperResearch(email,password)

browser.openResearch()
browser.addLogin()
browser.addSenha()   
browser.addCompany()
browser.selectProject()
browser.goToIssues()
browser.openAll()
browser.htmlGenerator()

id = []
titulo = []
status = []
descricao = []
empreendimento = []
etiqueta = []
responsavel = []
fase = []
tipo = []
area = []
prazo = []
prioridade =[]
ultimaAlteracao = []
primeiraAlteracao = []

    
dicionario = {}
for i in browser.htmlList:
    coleta = ScrapperColect(i)
    dicBase = coleta.dictionaryGeneration()
    
    id.append(dicBase.get("ID"))
    titulo.append(dicBase.get("Título"))    
    status.append(dicBase.get("Status")) 
    descricao.append(dicBase.get("Descrição")) 
    empreendimento.append(dicBase.get("Empreendimento"))
    etiqueta.append(dicBase.get("Etiqueta"))
    responsavel.append(dicBase.get("Responsável"))
    fase.append(dicBase.get("Fase"))
    tipo.append(dicBase.get("Tipo"))
    area.append(dicBase.get("Local"))
    prazo.append(dicBase.get("Prazo"))
    prioridade.append(dicBase.get("Prioridade"))
    ultimaAlteracao.append(dicBase.get("Última modificação"))
    primeiraAlteracao.append(dicBase.get("Primeira alteração"))
    
    
dicionario["ID"] = id
dicionario["Título"] = titulo
dicionario["Status"] = status
dicionario["Descrição"] = descricao
dicionario["Empreendimento"] = empreendimento
dicionario["Etiqueta"] = etiqueta
dicionario["Responsável"] = responsavel
dicionario["Fase"] = fase
dicionario["Tipo"] = tipo
dicionario["Local"] = area
dicionario["Prazo"] = prazo
dicionario["Prioridade"] = prioridade
dicionario["Última alteração"] = ultimaAlteracao
dicionario["Primeira alteração"] = primeiraAlteracao
# Out:
# {'status': [0, 'Realizando Login, email adicionado']}
# {'status': [1, 'Realizando login, senha adicionada']}
# {'status': [2, 'Companhia adicionada']}
# {'status': [3, 'Projeto selecionado']}
# {'status': [4, 'Área das incompatibilidades']}
# {'status': [5, 'Todos os dados abertos']}
# {'status': [6, 'Coletando incompatibilidade 0 de 98']}
# {'status': [6, 'Coletando incompatibilidade 1 de 98']}
# {'status': [6, 'Coletando incompatibilidade 2 de 98']}
# {'status': [6, 'Coletando incompatibilidade 3 de 98']}
# {'status': [6, 'Coletando incompatibilidade 4 de 98']}
# {'status': [6, 'Coletando incompatibilidade 5 de 98']}
# {'status': [6, 'Coletando incompatibilidade 6 de 98']}
# {'status': [6, 'Coletando incompatibilidade 7 de 98']}
# {'status': [6, 'Coletando incompatibilidade 8 de 98']}
# {'status': [6, 'Coletando incompatibilidade 9 de 98']}
# {'status': [6, 'Coletando incompatibilidade 10 de 98']}
# {'status': [6, 'Coletando incompatibilidade 11 de 98']}
# {'status': [6, 'Coletando incompatibilidade 12 de 98']}
# {'status': [6, 'Coletando incompatibilidade 13 de 98']}
# {'status': [6, 'Coletando incompatibilidade 14 de 98']}
# {'status': [6, 'Coletando incompatibilidade 15 de 98']}
# {'status': [6, 'Coletando incompatibilidade 16 de 98']}
# {'status': [6, 'Coletando incompatibilidade 17 de 98']}
# {'status': [6, 'Coletando incompatibilidade 18 de 98']}
# {'status': [6, 'Coletando incompatibilidade 19 de 98']}
# {'status': [6, 'Coletando incompatibilidade 20 de 98']}
# {'status': [6, 'Coletando incompatibilidade 21 de 98']}
# {'status': [6, 'Coletando incompatibilidade 22 de 98']}
# {'status': [6, 'Coletando incompatibilidade 23 de 98']}
# {'status': [6, 'Coletando incompatibilidade 24 de 98']}
# {'status': [6, 'Coletando incompatibilidade 25 de 98']}
# {'status': [6, 'Coletando incompatibilidade 26 de 98']}
# {'status': [6, 'Coletando incompatibilidade 27 de 98']}
# {'status': [6, 'Coletando incompatibilidade 28 de 98']}
# {'status': [6, 'Coletando incompatibilidade 29 de 98']}
# {'status': [6, 'Coletando incompatibilidade 30 de 98']}
# {'status': [6, 'Coletando incompatibilidade 31 de 98']}
# {'status': [6, 'Coletando incompatibilidade 32 de 98']}
# {'status': [6, 'Coletando incompatibilidade 33 de 98']}
# {'status': [6, 'Coletando incompatibilidade 34 de 98']}
# {'status': [6, 'Coletando incompatibilidade 35 de 98']}
# {'status': [6, 'Coletando incompatibilidade 36 de 98']}
# {'status': [6, 'Coletando incompatibilidade 37 de 98']}
# {'status': [6, 'Coletando incompatibilidade 38 de 98']}
# {'status': [6, 'Coletando incompatibilidade 39 de 98']}
# {'status': [6, 'Coletando incompatibilidade 40 de 98']}
# {'status': [6, 'Coletando incompatibilidade 41 de 98']}
# {'status': [6, 'Coletando incompatibilidade 42 de 98']}
# {'status': [6, 'Coletando incompatibilidade 43 de 98']}
# {'status': [6, 'Coletando incompatibilidade 44 de 98']}
# {'status': [6, 'Coletando incompatibilidade 45 de 98']}
# {'status': [6, 'Coletando incompatibilidade 46 de 98']}
# {'status': [6, 'Coletando incompatibilidade 47 de 98']}
# {'status': [6, 'Coletando incompatibilidade 48 de 98']}
# {'status': [6, 'Coletando incompatibilidade 49 de 98']}
# {'status': [6, 'Coletando incompatibilidade 50 de 98']}
# {'status': [6, 'Coletando incompatibilidade 51 de 98']}
# {'status': [6, 'Coletando incompatibilidade 52 de 98']}
# {'status': [6, 'Coletando incompatibilidade 53 de 98']}
# {'status': [6, 'Coletando incompatibilidade 54 de 98']}
# {'status': [6, 'Coletando incompatibilidade 55 de 98']}
# {'status': [6, 'Coletando incompatibilidade 56 de 98']}
# {'status': [6, 'Coletando incompatibilidade 57 de 98']}
# {'status': [6, 'Coletando incompatibilidade 58 de 98']}
# {'status': [6, 'Coletando incompatibilidade 59 de 98']}
# {'status': [6, 'Coletando incompatibilidade 60 de 98']}
# {'status': [6, 'Coletando incompatibilidade 61 de 98']}
# {'status': [6, 'Coletando incompatibilidade 62 de 98']}
# {'status': [6, 'Coletando incompatibilidade 63 de 98']}
# {'status': [6, 'Coletando incompatibilidade 64 de 98']}
# {'status': [6, 'Coletando incompatibilidade 65 de 98']}
# {'status': [6, 'Coletando incompatibilidade 66 de 98']}
# {'status': [6, 'Coletando incompatibilidade 67 de 98']}
# {'status': [6, 'Coletando incompatibilidade 68 de 98']}
# {'status': [6, 'Coletando incompatibilidade 69 de 98']}
# {'status': [6, 'Coletando incompatibilidade 70 de 98']}
# {'status': [6, 'Coletando incompatibilidade 71 de 98']}
# {'status': [6, 'Coletando incompatibilidade 72 de 98']}
# {'status': [6, 'Coletando incompatibilidade 73 de 98']}
# {'status': [6, 'Coletando incompatibilidade 74 de 98']}
# {'status': [6, 'Coletando incompatibilidade 75 de 98']}
# {'status': [6, 'Coletando incompatibilidade 76 de 98']}
# {'status': [6, 'Coletando incompatibilidade 77 de 98']}
# {'status': [6, 'Coletando incompatibilidade 78 de 98']}
# {'status': [6, 'Coletando incompatibilidade 79 de 98']}
# {'status': [6, 'Coletando incompatibilidade 80 de 98']}
# {'status': [6, 'Coletando incompatibilidade 81 de 98']}
# {'status': [6, 'Coletando incompatibilidade 82 de 98']}
# {'status': [6, 'Coletando incompatibilidade 83 de 98']}
# {'status': [6, 'Coletando incompatibilidade 84 de 98']}
# {'status': [6, 'Coletando incompatibilidade 85 de 98']}
# {'status': [6, 'Coletando incompatibilidade 86 de 98']}
# {'status': [6, 'Coletando incompatibilidade 87 de 98']}
# {'status': [6, 'Coletando incompatibilidade 88 de 98']}
# {'status': [6, 'Coletando incompatibilidade 89 de 98']}
# {'status': [6, 'Coletando incompatibilidade 90 de 98']}
# {'status': [6, 'Coletando incompatibilidade 91 de 98']}
# {'status': [6, 'Coletando incompatibilidade 92 de 98']}
# {'status': [6, 'Coletando incompatibilidade 93 de 98']}
# {'status': [6, 'Coletando incompatibilidade 94 de 98']}
# {'status': [6, 'Coletando incompatibilidade 95 de 98']}
# {'status': [6, 'Coletando incompatibilidade 96 de 98']}
# {'status': [6, 'Coletando incompatibilidade 97 de 98']}
# {'status': [11, 'Número 1 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 2 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 3 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 4 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 5 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 6 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 7 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 8 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 9 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 10 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 11 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 12 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 13 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 14 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 15 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 16 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 17 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 18 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 19 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 20 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 21 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 22 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 23 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 24 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 25 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 26 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 27 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 28 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 29 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 30 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 31 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 32 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 33 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 34 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 35 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 36 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 37 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 38 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 39 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 40 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 41 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 42 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 43 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 44 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 45 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 46 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 47 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 48 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 49 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 50 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 51 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 52 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 53 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 54 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 55 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 56 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 57 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 58 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 59 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 60 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 61 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 62 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 63 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 64 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 65 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 66 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 67 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 68 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 69 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 70 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 71 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 72 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 73 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 74 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 75 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 76 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 77 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 78 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 79 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 80 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 81 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 82 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 83 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 84 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 85 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 86 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 87 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 88 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 89 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 90 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 91 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 92 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 93 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 94 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 95 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 96 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 97 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [11, 'Número 98 coletado']}
# {'status': [13, 'Título coletado']}
# {'status': [12, 'Status coletado']}
# {'status': [14, 'Empreendimento coletado']}
# {'status': [15, 'Descrição coletada']}
# {'status': [16, 'Etiqueta coletada']}
# {'status': [17, 'Responsável coletado']}
# {'status': [18, 'Fase coletada']}
# {'status': [19, 'Tipo coletado']}
# {'status': [20, 'Localização coletada']}
# {'status': [21, 'Prazo coletado']}
# {'status': [22, 'Prioridade coletada']}
# {'status': [23, 'Última modificação coletada']}
# {'status': [23, 'Última modificação coletada']}

# %%
class Analysys():
    def __init__(self,dicionario:dict) -> None:
        self.dic = dicionario
        self.GlobalVariables() 
    
    def GlobalVariables(self):
        self.id1 = list()
        self.id2 = list()
        self.id3 = list()
        self.id4 = list()
        self.id5 = list()
        self.elemento1 = list()
        self.elemento2 = list()
        self.elemento3 = list()
        self.elemento4 = list()
        self.elemento5 = list()
        
        self.elementos = [self.id1,self.elemento1,self.id2,self.elemento2,self.id3,self.elemento3,self.id4,self.elemento4,self.id5,self.elemento5]
        
        self.disciplina1 = list()
        self.disciplina2 = list()
        self.disciplina3 = list() 
        self.disciplina4 = list() 
        self.disciplina5 = list() 
        self.disciplina6 = list() 
        self.disciplina7= list() 

        self.disciplinas = [self.disciplina1, self.disciplina2, self.disciplina3, self.disciplina4, self.disciplina5, self.disciplina6, self.disciplina7 ]
        
        self.updatedStatus = list()
        
        self.incompatibilidades = list()
        self.sugestoes = list()
        self.duvidas = list()
        
        self.primeirasAlteracoes = list()
        self.ultimasAlteracoes = list()
        
    def SeparadorInc(self):
        
        teste = list()
        for values in self.dic["Título"]:
            
            if "&" in values:
                splitValue = values.split("&")
            else:
                splitValue = values
            
            if type(splitValue) == list:
                countSplit = len(splitValue)
            else:
                countSplit = 1

            teste.append(splitValue)
        
        return teste
    
    def SeparadorID(self):
        
        teste2 = list()
        for i in range(len(self.SeparadorInc())):

            if type(self.SeparadorInc()[i]) == str:
                splitVar = self.SeparadorInc()[i].split("-")
                teste2.append(splitVar)
                
            if type(self.SeparadorInc()[i]) == list:
                variavel = []
                for j in range(len(self.SeparadorInc()[i])):
                    variavel = variavel + self.SeparadorInc()[i][j].split("-")
                teste2.append(variavel)
        return teste2
    
    def VerInc(self):
        for i in range(len(self.SeparadorID())):
            if len(self.SeparadorID()[i]) % 2 != 0:
                for j in range(len(self.elementos)):
                    self.elementos[j].append(None)
            
            else:
                for j in range(len(self.elementos)):
                    try:
                        self.elementos[j].append(self.SeparadorID()[i][j])
                    except IndexError:
                        self.elementos[j].append(None)
                        
    def VerID(self):
        
        for j in range(len(self.elementos)):
            for i in range(len(self.elementos[j])):

                if not self.elementos[j][i]:
                    continue

                else:
                    
                    if j%2 == 0:
                        try:
                            self.elementos[j][i] = int(self.elementos[j][i])
                        except ValueError:
                            self.elementos[j][i] = None
    def ErrorID(self):                            
        for i in range(len(self.elementos[0])):
            if not self.elementos[0][i]:
                
                for j in range(1,len(self.elementos)):
                    self.elementos[j][i] = "VERIFICAR"
        
                for j in range(0,len(self.disciplinas)):
                    self.disciplinas[j][i] = "VERIFICAR"
        
                self.updatedStatus[i] = "VERIFICAR"
        
                self.incompatibilidades[i] = "VERIFICAR"
                self.sugestoes[i] = "VERIFICAR"
                self.duvidas[i] = "VERIFICAR"

                self.dic["Empreendimento"][i] = "VERIFICAR"
                self.dic["Responsável"][i] = "VERIFICAR"
                self.dic["Fase"][i] = "VERIFICAR"
                self.dic["Tipo"][i] = "VERIFICAR"
                self.dic["Local"][i] = "VERIFICAR"
                self.dic["Prazo"][i] = "VERIFICAR"
                self.dic["Prioridade"][i] = "VERIFICAR"
                
                self.elementos[0][i] = "VERIFICAR"

    def ErrorTxt(self):
        msgAvaliacao = "AVALIAR ESCRITA"
        
        for i in range(len(self.dic["Tipo"])): 
            errorList = ["issue","remark","request","inquiry", "major", "on hold", "minor",]
            
            if self.dic["Tipo"][i].lower() in errorList:
                self.dic["Tipo"][i] = msgAvaliacao
            
            if self.dic["Prioridade"][i].lower() in errorList:
                self.dic["Prioridade"][i] = msgAvaliacao
            
            if self.dic["Local"][i] == "-":
                self.dic["Local"][i] = msgAvaliacao
                
            if self.dic["Fase"][i] == "Undecided":
                self.dic["Fase"][i] = msgAvaliacao
            
            if self.disciplinas[0][i] == "-":
                for j in range(0,len(self.disciplinas)):
                    self.disciplinas[j][i] = msgAvaliacao
            
            if not self.incompatibilidades[i] and not self.sugestoes[i] and not self.duvidas[i]:
                self.incompatibilidades[i] = msgAvaliacao
                self.sugestoes[i] = msgAvaliacao
                self.duvidas[i] = msgAvaliacao
            
    def GetDisciplinas(self):
        for titulos in self.dic["Etiqueta"]:
            etiquetas = titulos.split(",")
            
            if len(etiquetas)<=7:
                for i in range(len(self.disciplinas)):
                    try:
                        self.disciplinas[i].append(etiquetas[i]) 
                    except IndexError:
                        self.disciplinas[i].append(None) 
        return etiquetas
    
    def GetStatus(self):
        for status in self.dic["Status"]:
            
            if status.replace(" ","").upper() == "Active".upper():
                self.updatedStatus.append("Aberta")
                
            elif status.replace(" ","").upper() == "Resolved".upper():
                self.updatedStatus.append("Resolvida")
            
            elif status.replace(" ","").upper() == "Closed".upper():
                self.updatedStatus.append("Resolvida")
                
    def GetMarcadores(self):
        for j in range(len(self.dic["Descrição"])):
            splitDs01 = self.dic["Descrição"][j].split("-")
            
            incompatibilidade = None
            sugestao = None
            duvida = None
            for i in range(len(splitDs01)):
                
                if not splitDs01[i]:
                    splitDs01[i] = None
                elif len(splitDs01[i])>1:
                    splitDs01[i] = None 

                    
                if splitDs01[i] == "I":
                    incompatibilidade = splitDs01[i]
                elif splitDs01[i] == "S":
                    sugestao = splitDs01[i]
                elif splitDs01[i] == "D":
                    duvida = splitDs01[i]

                   

            self.incompatibilidades.append(incompatibilidade)
            self.sugestoes.append(sugestao)
            self.duvidas.append(duvida) 
    
    def GetFirstAlteration(self):
        for p_alteracao in self.dic["Primeira alteração"]:
            split01 = p_alteracao.split(" ")[-2]
            self.primeirasAlteracoes.append(split01.replace("-","/"))
    
    def GetLastAlteration(self):
        for u_alteracao in self.dic["Última alteração"]:
            split01 = u_alteracao.split(" ")[-2]
            self.ultimasAlteracoes.append(split01.replace("-","/")) 
    
    def DicFiltered(self):
        dicionarioFiltrado = dict()

        dicionarioFiltrado["ID"] = self.dic["ID"]
        dicionarioFiltrado["ID-ELEMENTO 01"] = self.elementos[0]
        dicionarioFiltrado["ELEMENTO 01"] = self.elementos[1]
        dicionarioFiltrado["ID-ELEMENTO 02"] = self.elementos[2]
        dicionarioFiltrado["ELEMENTO 02"] = self.elementos[3]
        dicionarioFiltrado["ID-ELEMENTO 03"] = self.elementos[4]
        dicionarioFiltrado["ELEMENTO 03"] = self.elementos[5]
        dicionarioFiltrado["ID-ELEMENTO 04"] = self.elementos[6]
        dicionarioFiltrado["ELEMENTO 04"] = self.elementos[7]
        dicionarioFiltrado["ID-ELEMENTO 05"] = self.elementos[8]
        dicionarioFiltrado["ELEMENTO 05"] = self.elementos[9]
        dicionarioFiltrado["DISCIPLINA 01"] = self.disciplinas[0]
        dicionarioFiltrado["DISCIPLINA 02"] = self.disciplinas[1]
        dicionarioFiltrado["DISCIPLINA 03"] = self.disciplinas[2]
        dicionarioFiltrado["DISCIPLINA 04"] = self.disciplinas[3]
        dicionarioFiltrado["DISCIPLINA 05"] = self.disciplinas[4]
        dicionarioFiltrado["DISCIPLINA 06"] = self.disciplinas[5]
        dicionarioFiltrado["DISCIPLINA 07"] = self.disciplinas[6]
        dicionarioFiltrado["STATUS"] = self.updatedStatus
        dicionarioFiltrado["EMPREENDIMENTO"] = self.dic["Empreendimento"]
        dicionarioFiltrado["RESPONSÁVEL"] = self.dic["Responsável"]
        dicionarioFiltrado["FASE"] = self.dic["Fase"]
        dicionarioFiltrado["TIPO"] = self.dic["Tipo"]
        dicionarioFiltrado["LOCAL"] = self.dic["Local"]
        dicionarioFiltrado["PRAZO"] = self.dic["Prazo"]
        dicionarioFiltrado["PRIORIDADE"] = self.dic["Prioridade"]
        dicionarioFiltrado["PRIMEIRA ALTERAÇÃO"] = self.primeirasAlteracoes
        dicionarioFiltrado["ÚLTIMA ALTERAÇÃO"] = self.ultimasAlteracoes
        dicionarioFiltrado["MARCADOR 01"] = self.incompatibilidades
        dicionarioFiltrado["MARCADOR 02"] = self.sugestoes
        dicionarioFiltrado["MARCADOR 03"] = self.duvidas
        
        return dicionarioFiltrado
    
    def Filter(self):
            self.SeparadorInc()
            self.SeparadorID()
            self.VerInc()
            self.VerID()
            self.GetDisciplinas()
            self.GetStatus()
            self.GetMarcadores()
            self.GetFirstAlteration()
            self.GetLastAlteration()
            self.ErrorID()
            self.ErrorTxt()

# %%
_dicionario = dicionario.copy()

a = Analysys(_dicionario)
a.Filter()

# %%
dicionario_ = a.DicFiltered()

# %% [markdown]
# MONTAR O CSV

# %%
dbBuildCSV(dicionario_,"teste.csv")
# Out:
#     ID ID-ELEMENTO 01         ELEMENTO 01 ID-ELEMENTO 02 ELEMENTO 02  \
# 0    1           3088              Escada           None        None
# 1    2           3088              Escada           None        None
# 2    3           9604  Shaft/Coluna falsa           9873       Pilar
# 3    4           3500                Laje           None        None
# 4    5           8899            Elevador           None        None
# ..  ..            ...                 ...            ...         ...
# 93  94           9873               Pilar           None        None
# 94  95           3500                Laje           4043   Alvenaria
# 95  96           7895           Esquadria           9873       Pilar
# 96  97           3088              Escada           None        None
# 97  98           9873               Pilar           None        None
#
#    ID-ELEMENTO 03 ELEMENTO 03 ID-ELEMENTO 04 ELEMENTO 04 ID-ELEMENTO 05  ...  \
# 0            None        None           None        None           None  ...
# 1            None        None           None        None           None  ...
# 2            None        None           None        None           None  ...
# 3            None        None           None        None           None  ...
# 4            None        None           None        None           None  ...
# ..            ...         ...            ...         ...            ...  ...
# 93           None        None           None        None           None  ...
# 94           4496        Viga           9873       Pilar           None  ...
# 95           None        None           None        None           None  ...
# 96           None        None           None        None           None  ...
# 97           None        None           None        None           None  ...
#
#                      FASE                    TIPO                    LOCAL  \
# 0   Construção virtual 01  Falha de representação  Pavimento Semienterrado
# 1   Construção virtual 01                Ausência           Pavimento Tipo
# 2   Construção virtual 01                Conflito           Pavimento Tipo
# 3   Construção virtual 01  Inconsistência Técnica           Pavimento Tipo
# 4   Construção virtual 01  Inconsistência Técnica        Pavimento Coberta
# ..                    ...                     ...                      ...
# 93  Construção virtual 01  Falha de representação        Pavimento Coberta
# 94  Construção virtual 01  Falha de representação                    Geral
# 95  Construção virtual 01                Conflito  Pavimento Semienterrado
# 96  Construção virtual 01                Ausência  Pavimento Semienterrado
# 97  Construção virtual 01    Concepção de projeto                    Geral
#
#          PRAZO PRIORIDADE PRIMEIRA ALTERAÇÃO ÚLTIMA ALTERAÇÃO MARCADOR 01  \
# 0   07-02-2022     NORMAL         08/02/2022       18/08/2022           I
# 1   07-02-2022     NORMAL         08/02/2022       22/08/2022           I
# 2   07-02-2022    CRÍTICO         08/02/2022       18/08/2022           I
# 3   07-02-2022     NORMAL         08/02/2022       18/08/2022           I
# 4   07-02-2022    CRÍTICO         08/02/2022       18/08/2022           I
# ..         ...        ...                ...              ...         ...
# 93           -    SIMPLES         27/06/2022       20/08/2022           I
# 94           -    CRÍTICO         27/06/2022       20/08/2022           I
# 95           -     NORMAL         27/06/2022       20/08/2022        None
# 96           -     NORMAL         29/06/2022       20/08/2022           I
# 97           -     NORMAL         29/06/2022       20/08/2022        None
#
#    MARCADOR 02 MARCADOR 03
# 0         None        None
# 1         None        None
# 2         None        None
# 3         None        None
# 4         None        None
# ..         ...         ...
# 93        None        None
# 94        None        None
# 95           S        None
# 96        None        None
# 97        None           D
#
# [98 rows x 31 columns]
